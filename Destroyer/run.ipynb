# %%
# !python train.py --dataset=ped2 --resume=0_g_best_auc_ped2 --iters=15000 --val_interval=100
# Out:
# ...
# /home/sha/Access/Paper-Making-Anomalies-More-Anomalous/Destroyer
# ...
# cuda
#
# ------------------------------train cfg------------------------------
# mode: train
# dataset: ped2
# img_size: (256, 256)
# data_root: /home/sha/datasets/
# work_num: 0
# sch: False
# show_status: False
# manualseed: -1
# batch_size: 4
# train_data: /home/sha/datasets/ped2/training/frames/
# test_data: /home/sha/datasets/ped2/testing/frames/
# a_lr: 0.0001
# g_lr: 0.0001
# d_lr: 1e-05
# l2: 0.0001
# resume: weights/0_g_best_auc_ped2.pth
# iters: 15000
# save_interval: 1000
# val_interval: 100
# epoch_size: 3750
#
#
# ...
# Dataloader Ok!
# -----------------------------------------------------------
# [Data Size]: 16
# [Batch Size]: 4
# [One epoch]: 4 step   # (Data Size / Batch Size)
# [Epoch & Iteration]: 3750 epoch & 15000 step
# -----------------------------------------------------------
# ...
# Using cache found in /home/sha/.cache/torch/hub/pytorch_vision_v0.10.0
# ...

# %%
# !python eval.py --dataset=ped2 --trained_model=a_best_auc_ped2 --show_status=True
# Out:
# ...
# /home/sha/Access/Paper-Making-Anomalies-More-Anomalous/Destroyer
# ...
#
# ------------------------------test cfg------------------------------
# mode: test
# dataset: ped2
# img_size: (256, 256)
# data_root: /home/sha/datasets/
# show_status: True
# save_data: False
# gaussian: False
# test_data: /home/sha/datasets/ped2/testing/frames/
# trained_model: 0_a_best_auc_ped2
#
# Using cache found in /home/sha/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/sha/anaconda3/envs/dvaa/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python eval.py --dataset=ped2 --trained_model=a_best_auc_ped2 --show_status=True --gaussian=True
# Out:
# ...
# /home/sha/Access/Paper-Making-Anomalies-More-Anomalous/Destroyer
# ...
#
# ------------------------------test cfg------------------------------
# mode: test
# dataset: ped2
# img_size: (256, 256)
# data_root: /home/sha/datasets/
# show_status: True
# save_data: False
# gaussian: True
# test_data: /home/sha/datasets/ped2/testing/frames/
# trained_model: a_best_auc_ped2
#
# Using cache found in /home/sha/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/sha/anaconda3/envs/dvaa/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
